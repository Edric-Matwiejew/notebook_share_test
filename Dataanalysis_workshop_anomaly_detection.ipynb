# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from pathlib import Path
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder
from sklearn.ensemble import IsolationForest
import plotly.express as px
from sklearn.decomposition import PCA

# %%
# will have to adjust path, based on where the CSV file with the live evaluation entries is saved on your private google drive.
data_path = Path('/content/gdrive/MyDrive/CSIRO_workshop/Dataanalysis_workshop.csv')

# %%
df = pd.read_csv(data_path)

# %%
df
# Out:
#   State  Year of Birth (YYYY) Country of Birth  ... Citizen/PR First Language gender
# 0   VIC                  1997          Germany  ...         No         german  woman
# 1    WA                  1972              USA  ...        Yes        english  woman
# 2   NSW                  1995        Australia  ...        Yes        english  woman
# 3    WA                  1999           Israel  ...        Yes         hebrew    man
# 4    WA                  2000        Australia  ...        Yes        english    man
# 5    WA                  1990        Australia  ...        Yes        english    man
# 6    WA                  2001          Germany  ...        Yes         german    man
# 7    WA                  1992        Australia  ...        Yes        english    man
# 8    WA                  1994        Australia  ...        Yes        english    man
#
# [9 rows x 8 columns]

# %%
le = OrdinalEncoder()
df_transformed = le.fit_transform(df)

# %%
le = LabelEncoder()
df_transformed = df.copy()
for col in df_transformed.select_dtypes(include='O').columns:
    df_transformed[col]=le.fit_transform(df_transformed[col])

# %%
df_transformed
# Out:
# array([[1., 5., 1., 2., 0., 0., 1., 1.],
#        [2., 0., 3., 2., 0., 1., 0., 1.],
#        [0., 4., 0., 0., 0., 1., 0., 1.],
#        [2., 6., 2., 1., 0., 1., 2., 0.],
#        [2., 7., 0., 1., 0., 1., 0., 0.],
#        [2., 1., 0., 2., 0., 1., 0., 0.],
#        [2., 8., 1., 1., 0., 1., 1., 0.],
#        [2., 2., 0., 1., 0., 1., 0., 0.],
#        [2., 3., 0., 0., 0., 1., 0., 0.]])

# %%
clf = IsolationForest(random_state=0).fit_predict(df_transformed)

# %%
df['anomaly'] = clf

# %%
df
# Out:
#   State  Year of Birth (YYYY) Country of Birth  ... First Language gender anomaly
# 0   VIC                  1997          Germany  ...         german  woman      -1
# 1    WA                  1972              USA  ...        english  woman      -1
# 2   NSW                  1995        Australia  ...        english  woman      -1
# 3    WA                  1999           Israel  ...         hebrew    man      -1
# 4    WA                  2000        Australia  ...        english    man       1
# 5    WA                  1990        Australia  ...        english    man       1
# 6    WA                  2001          Germany  ...         german    man       1
# 7    WA                  1992        Australia  ...        english    man       1
# 8    WA                  1994        Australia  ...        english    man       1
#
# [9 rows x 9 columns]

# %%
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df_transformed)
df['pca-one'] = pca_result[:,0]
df['pca-two'] = pca_result[:,1]
print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))
# Out:
# Explained variation per principal component: [0.72673848 0.14813161]

# %%
df
# Out:
#   State  Year of Birth (YYYY) Country of Birth  ... anomaly   pca-one   pca-two
# 0   VIC                  1997          Germany  ...      -1 -0.965266  0.772141
# 1    WA                  1972              USA  ...      -1  4.236012  2.000666
# 2   NSW                  1995        Australia  ...      -1 -0.067963 -1.445862
# 3    WA                  1999           Israel  ...      -1 -2.147357  1.597724
# 4    WA                  2000        Australia  ...       1 -2.941025 -0.721377
# 5    WA                  1990        Australia  ...       1  3.037246 -0.544903
# 6    WA                  2001          Germany  ...       1 -4.016732  0.491210
# 7    WA                  1992        Australia  ...       1  1.967444 -0.898167
# 8    WA                  1994        Australia  ...       1  0.897641 -1.251432
#
# [9 rows x 11 columns]

# %%
df["anomaly"] = df["anomaly"].astype(str)
fig = px.scatter(df, x="pca-one", y="pca-two", color="anomaly",
                 hover_data=['State', 'Country of Birth', 'highest academic degree', 'Identity as aboriginal/torres strait islander', 'Citizen/PR'],
                 color_discrete_sequence=["indianred", "mediumblue"])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0755366a-1ef8-4004-9a2a-27c1e2ed2447" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0755366a-1ef8-4004-9a2a-27c1e2ed2447")) {
#                     Plotly.newPlot(
#                         '0755366a-1ef8-4004-9a2a-27c1e2ed2447',
#                         [{"customdata": [["VIC", "Germany", "Master Degree", "No", "No"], ["WA", "USA", "Master Degree", "No", "Yes"], ["NSW", "Australia", "Bachelor Degree", "No", "Yes"], ["WA", "Israel", "High School Diploma", "No", "Yes"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "anomaly=-1<br>pca-one=%{x}<br>pca-two=%{y}<br>State=%{customdata[0]}<br>Country of Birth=%{customdata[1]}<br>highest academic degree=%{customdata[2]}<br>Identity as aboriginal/torres strait islander=%{customdata[3]}<br>Citizen/PR=%{customdata[4]}", "legendgroup": "anomaly=-1", "marker": {"color": "indianred", "symbol": "circle"}, "mode": "markers", "name": "anomaly=-1", "showlegend": true, "type": "scatter", "x": [-0.9652655417955023, 4.236011755891074, -0.06796331137686472, -2.1473569301873927], "xaxis": "x", "y": [0.7721412019699724, 2.0006661182875662, -1.4458620667487083, 1.5977236083810868], "yaxis": "y"}, {"customdata": [["WA", "Australia", "High School Diploma", "No", "Yes"], ["WA", "Australia", "Master Degree", "No", "Yes"], ["WA", "Germany", "High School Diploma", "No", "Yes"], ["WA", "Australia", "High School Diploma", "No", "Yes"], ["WA", "Australia", "Bachelor Degree", "No", "Yes"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "anomaly=1<br>pca-one=%{x}<br>pca-two=%{y}<br>State=%{customdata[0]}<br>Country of Birth=%{customdata[1]}<br>highest academic degree=%{customdata[2]}<br>Identity as aboriginal/torres strait islander=%{customdata[3]}<br>Citizen/PR=%{customdata[4]}", "legendgroup": "anomaly=1", "marker": {"color": "mediumblue", "symbol": "circle"}, "mode": "markers", "name": "anomaly=1", "showlegend": true, "type": "scatter", "x": [-2.941025119326313, 3.037246412489347, -4.016731639149163, 1.9674435953147213, 0.8976407781400955], "xaxis": "x", "y": [-0.721377101990298, -0.5449031163077822, 0.4912103317647409, -0.8981673638881199, -1.2514316114684572], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpola ...
